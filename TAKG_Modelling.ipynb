# %% [markdown]
# # Description
#
# This notebook will model (step 3 below) the football players data (following completion of step 1 & 2) incorporating the time dimension.
#
# - 1. Create Tables
# - 2. Download Data
# - 3. Model the data & Insert
# - 4. Consume the data
#
# ![TAKG-Model-2.jpg](attachment:TAKG-Model-2.jpg)

# %% [markdown]
# ## 5 Functionalities
#      - ### 1. What awards did the player won and when? e.g. European golden shoe --> Wikidata
#      - ### 2. What major football events did the player participate in? e.g World Cup --> Wikidata
#      - ### 3. What is the current and maximum market value (& when) of a given player? --> Transfer Market
#      - ### 4. What is the club transfer history of a player? --> Transfer Market
#      - ### 5. Which players played with a given player between given the time range? --> Wikidata

# %% [markdown]
# - I would like to know the teammates of Miroslav Klose between 2010 and 2012. Thus, your query first checks if there is some relevant information in your graph already. (THINKING)
#
# - Based on this output, i can decide if I still want to extend my knowledge. (LOOKING UP NEW INFORMATION)
#
# - Your functionalities retrieve the demanded knowledge and store it in your graph (including the information when it was retrieved from which source) (LEARNING)
