# %%
# %reload_ext jupyter-rdfify

# %%
import rdflib
from rdflib.namespace import FOAF, RDF, OWL, RDFS, XSD

# %%
# %%rdf turtle
#
# @prefix :<http://example.org/ex1#> .
# @prefix dc: <http://example.org/> .
# @prefix RDFS:<http://www.w3.org/2000/01/rdf-schema#>.
#
# #dc:Player a RDFS:Class.
# dc:Player a RDFS:Class.

# %%
# %%rdf turtle
#
# @prefix :<http://example.org/ex1#> .
# @prefix dc: <http://example.org/> .
# @prefix RDFS:<http://www.w3.org/2000/01/rdf-schema#>.
#
# #dc:Player a RDFS:Class.
# dc:Player a RDFS:Class;
#           :played_for dc:Team;
#           :association dc:Football_Player;
#           :hasTransferID dc:TransferMarketID.
#
# dc:Team :association dc:Football_Club;
#         :leagueName dc:League;
#         :country dc:Country.

# %%
# %%rdf turtle
#
# @prefix :<http://example.org/ex1#> .
# @prefix dc: <http://example.org/> .
# @prefix RDFS:<http://www.w3.org/2000/01/rdf-schema#>.
# @prefix tm:<https://www.transfermarkt.com/cristiano-ronaldo/profil/spieler/>.
#
# dc:Player a RDFS:Class.
#
# dc:Ronaldo a dc:Player;
#           :played_for dc:Manchester_United;
#           :association dc:Football_Player;
#           :hasTransferID tm:8198.
#
#
# dc:Manchester_United a dc:Team;
#         :association dc:Football_Club;
#         :leagueName dc:EnglishP_Premier_League;
#         :country dc:UK.

# %%
# %%rdf turtle
# @prefix owl:<http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix takg: <http://takg.com/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix wiki: <http://www.wikidata.org/entity/>.
#
# <http://www.wikidata.org/entity/Q10413488> takg:DOB "1989-12-28T00:00:00Z" ;
#     takg:fullName "Harry Arter" ;
#     takg:sex <http://www.wikidata.org/entity/Q6581097> ;
#     takg:team <http://www.wikidata.org/entity/Q163547>;
#         #<http://www.wikidata.org/entity/Q16841704>,
#         #<http://www.wikidata.org/entity/Q18528>,
#         #<http://www.wikidata.org/entity/Q19462>,
#         #<http://www.wikidata.org/entity/Q19568>,
#         #<http://www.wikidata.org/entity/Q19575>,
#         #<http://www.wikidata.org/entity/Q2511419>,
#         #<http://www.wikidata.org/entity/Q3590338>,
#         #<http://www.wikidata.org/entity/Q9306853>,
#         #<http://www.wikidata.org/entity/Q163547> ;
#     takg:transferMarketID takg:55742 .

# %%
# %%rdf turtle
# @prefix owl:<http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix takg: <http://takg.com/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix wiki: <http://www.wikidata.org/entity/>.
# @prefix TFMID: <https://www.transfermarkt.com/transfermarkt/profil/spieler/>.
#
#
# <http://www.wikidata.org/entity/Q615> takg:DOB "1987-06-24T00:00:00Z" ;
#     takg:fullName "Lionel Messi" ;
#     takg:sex <http://www.wikidata.org/entity/Q6581097> ;
#     takg:team <http://www.wikidata.org/entity/Q7156>;
#     takg:transferMarketID <https://www.transfermarkt.com/transfermarkt/profil/spieler/28003> .
